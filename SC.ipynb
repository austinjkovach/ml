# %%
import os
import tarfile
from six.moves import urllib

DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml/master/"
STARCRAFT_PATH = os.path.join("datasets", "starcraft")

# %%
import pandas as pd

def load_data(starcraft_path=STARCRAFT_PATH):
    csv_path = os.path.join(starcraft_path, "season1.csv")
    return pd.read_csv(csv_path)

# %%
starcraft = load_data()
starcraft.tail()
# Out:
#         Date W/L Race     Opponent   MMR        Map  \
# 405  3/11/18   W    T         Mark  3956  Backwater
# 406  3/11/18   W    P  <Yikes>Dain  4574   Catalyst
# 407  3/11/18   W    Z        Wichi  4561  Backwater
# 408  3/11/18   L    Z     HankHill  4674  Backwater
# 409  3/11/18   W    Z   penduloSFX  4696  Blackpink
#
#                               Opponent's Strat  \
# 405                                       Mech
# 406  Zealot Adept pushout, Void, ShieldBattery
# 407                               HGP LingBane
# 408                      HGP -> Muta -> Lurker
# 409                                HGP -> Muta
#
#                              Mistakes/Improvement  \
# 405   Lost lots of lings to hellions, late vipers
# 406  Didn't surround adepts, roaches bottlenecked
# 407            Missed injects, could micro better
# 408                Went for roach push, not hydra
# 409                                           NaN
#
#                                 Notes  \
# ...

# %%
starcraft.describe()
# Out:
#           Date  W/L Race  Opponent  MMR         Map Opponent's Strat  \
# count      410  410  410       410  410         408              337
# unique      44    2    7       363  298           8              233
# top     3/4/18    W    T  IIIIIIII  ???  Acid Plant          BioTank
# freq        30  222  141         9   22         107               16
#
#        Mistakes/Improvement    Notes     Tags
# count                   284      148      289
# unique                  282      134      125
# top                 Therapy  Therapy  Therapy
# freq                      2        9       53

# %%
starcraft["Map"].value_counts()
# Out:
# Acid Plant     107
# Blackpink       95
# Backwater       92
# Catalyst        67
# Eastwatch       35
# Abiogenesis      9
# Catayst          2
# Abiogensis       1
# Name: Map, dtype: int64

# %%
import matplotlib.pyplot as plt

starcraft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 410 entries, 0 to 409
# Data columns (total 10 columns):
# Date                    410 non-null object
# W/L                     410 non-null object
# Race                    410 non-null object
# Opponent                410 non-null object
# MMR                     410 non-null object
# Map                     408 non-null object
# Opponent's Strat        337 non-null object
# Mistakes/Improvement    284 non-null object
# Notes                   148 non-null object
# Tags                    289 non-null object
# dtypes: object(10)
# memory usage: 32.1+ KB

# %%
starcraft.head()
# Out:
#       Date W/L  Race      Opponent   MMR         Map  \
# 0  1/23/18   W     Z           Fox  4431   Eastwatch
# 1  1/23/18   W     Z        supmax  4244  Acid Plant
# 2  1/23/18   W     Z       Shahzad  4491  Abiogensis
# 3  1/23/18   W     P          tipu  4393   Backwater
# 4  1/23/18   L  P(R)  <Capt>Xenonn  4489   Eastwatch
#
#            Opponent's Strat  \
# 0  Ling Bane -> Roach Hydra
# 1                     13/12
# 2                       HGP
# 3      Early Adept pressure
# 4      Blink Stalker Timing
#
#                                 Mistakes/Improvement  \
# 0  Overcommitting vs hydras, not enough multprong...
# 1             Wait for lings to pop before engaging?
# 2   Not scouting for roaches/spire tech, SB @36, @44
# 3                           No early defensive lings
# 4                No detection for DTs, Ravager micro
#
#                                                Notes        Tags
# 0           Eastwatch still susceptible to Ling/Bane  Overcommit
# ...
